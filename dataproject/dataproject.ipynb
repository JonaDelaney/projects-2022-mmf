# %%
import numpy as np
import pandas as pd
import datetime

import pandas_datareader # install with `pip install pandas-datareader`
import pydst # install with `pip install git+https://github.com/elben10/pydst`
import matplotlib.pyplot as plt

# %%
Dst = pydst.Dst(lang='en')

# %%
print(type(Dst))
# Out:
# <class 'pydst.pydst.Dst'>

# %% [markdown]
# # Stock prices and employment level

# %% [markdown]
# We seek to investigate the correlation between stock prices and employment levels in Denmark. Our data is fetched from Statistikbanken.dk.

# %% [markdown]
# **Fetching emplyment data**

# %%
Dst.get_subjects()
# Out:
#    id                    desc  active  hasSubjects
# 0   1                  People    True         True
# 1   2       Labour and income    True         True
# 2   3                 Economy    True         True
# 3   4       Social conditions    True         True
# 4   5  Education and research    True         True
# 5   6                Business    True         True
# 6   7               Transport    True         True
# 7   8     Culture and leisure    True         True
# 8   9  Environment and energy    True         True
# 9  19                   Other    True         True

# %%
tables = Dst.get_tables(subjects=['2'])
print(type(tables))
display(tables)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            id                                               text  \
# 0     AKU100K            Seasonally adjusted labour force status
# 1     AKU101K  Seasonally adjusted labour force status in per...
# 2     AKU110K                                Labour force status
# 3     AKU111K                  Labour force status in percentage
# 4     AKU120K                                Labour force status
# ..        ...                                                ...
# 233  PENFOR11                           Value of pension schemes
# 234  PENFOR12                           Value of pension schemes
# 235     PENS6  Value of pension schemes (except special schem...
# 236  PENFOR20                           Value of pension schemes
# 237  PENINDB1                 Persons with pension contributions
#
#              unit             updated firstPeriod latestPeriod  active  \
# 0    1,000 people 2022-03-09 08:00:00      2008Q1       2021Q4    True
# 1        Per cent 2022-03-09 08:00:00      2008Q1       2021Q4    True
# 2    1,000 people 2022-03-09 08:00:00      2008Q1       2021Q4    True
# 3        Per cent 2022-03-09 08:00:00      2008Q1       2021Q4    True
# 4    1,000 people 2022-03-09 08:00:00      2008Q1       2021Q4    True
# ..            ...                 ...         ...          ...     ...
# 233             - 2021-08-25 08:00:00        2015         2020    True
# 234        Number 2021-08-25 08:00:00        2015         2020    True
# 235             - 2021-08-25 08:00:00        2015         2020    True
# 236             - 2021-08-27 08:00:00        2015         2020    True
# 237             - 2021-11-29 08:00:00        2005         2020    True
#
#                                              variables
# 0                            [employment status, time]
# 1                            [employment status, time]
# 2                  [employment status, age, sex, time]
# 3                  [employment status, age, sex, time]
# 4                    [employment status, region, time]
# ..                                                 ...
# 233  [kind of pension, taxation, age, sex, unit, time]
# 234  [family type, age, sex, price unit, value of p...
# 235  [kind of pension, company type, unit, family t...
# 236  [kind of pension, company type, age, populatio...
# 237    [region, unit, sex, age, type of pension, time]
#
# [238 rows x 8 columns]

# %%
# We select the following table

tables[tables.id == 'AKU101K']
# Out:
#         id                                               text      unit  \
# 1  AKU101K  Seasonally adjusted labour force status in per...  Per cent
#
#               updated firstPeriod latestPeriod  active  \
# 1 2022-03-09 08:00:00      2008Q1       2021Q4    True
#
#                    variables
# 1  [employment status, time]

# %%
indk_vars = Dst.get_variables(table_id='AKU101K')
indk_vars
# Out:
#            id               text  elimination   time  \
# 0  BESKSTATUS  employment status        False  False
# 1         Tid               time        False   True
#
#                                               values
# 0  [{'id': 'BFK', 'text': 'Employment rate'}, {'i...
# 1  [{'id': '2008K1', 'text': '2008Q1'}, {'id': '2...

# %%
for id in ['BESKSTATUS']:
    print(id)
    values = indk_vars.loc[indk_vars.id == id,['values']].values[0,0]
    for value in values:      
        print(f' id = {value["id"]}, text = {value["text"]}')
# Out:
# BESKSTATUS
#  id = BFK, text = Employment rate
#  id = LPCT, text = ILO-unemployment rate
#  id = EFK, text = Economic activity rate

# %%
variables = {'BESKSTATUS':['BFK'],'Tid':['*']}
empl = Dst.get_data(table_id = 'AKU101K', variables=variables)
empl.sort_values(by=['TID'], inplace=True)
empl.head(5)
# Out:
#         BESKSTATUS     TID  INDHOLD
# 0  Employment rate  2008Q1     76.7
# 1  Employment rate  2008Q2     76.3
# 2  Employment rate  2008Q3     76.2
# 3  Employment rate  2008Q4     76.0
# 4  Employment rate  2009Q1     75.1

# %%
# Code for setting 'TID' as index
# empl.set_index('TID', inplace=True)

# %%
# Plot of employment, quarterly

empl.plot(x = 'TID', y = 'INDHOLD', kind = 'line', ylabel = "Employment rate", xlabel = "Time", label = " ")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Employment rate'>

# %% [markdown]
# **Fetching stock market index data**

# %%
tables = Dst.get_tables(subjects=['3'])
print(type(tables))
display(tables)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           id                                               text    unit  \
# 0       NAN1                                  Demand and supply       -
# 1      VNAN1      Versionstable NAN1 - Demand and supply (year)       -
# 2       NAN2         Real gross national disposable income etc.   M dkk
# 3       NAN3  Consumption, disposable income and saving for ...       -
# 4       NKN1                                  Demand and supply       -
# ..       ...                                                ...     ...
# 360   DNBSTP             Transactions using Danish issued cards       -
# 361   DNBSKK                            ATMs and card terminals  Number
# 362   DNBSHI                           Withdrawals and deposits       -
# 363  DNBSVKO                       Credit transfers in currency  Number
# 364  DNBSIKO         Domestic credit transfers in Danish kroner       -
#
#                 updated firstPeriod latestPeriod  active  \
# 0   2022-03-31 08:00:00        1966         2021    True
# 1   2022-03-31 08:00:00        1966         2021    True
# 2   2022-03-31 08:00:00        1966         2021    True
# 3   2022-03-31 08:00:00        1995         2021    True
# 4   2022-03-31 08:00:00      1990Q1       2021Q4    True
# ..                  ...         ...          ...     ...
# 360 2022-02-15 08:00:00      2016Q1       2021Q4    True
# 361 2022-02-15 08:00:00      2016Q1       2021Q4    True
# 362 2022-02-15 08:00:00      2016Q1       2021Q4    True
# 363 2022-02-15 08:00:00      2016Q1       2021Q4    True
# 364 2022-02-15 08:00:00      2016Q1       2021Q4    True
#
#                                              variables
# 0                      [transaction, price unit, time]
# 1             [version, transaction, price unit, time]
# 2                      [transaction, price unit, time]
# 3                      [transaction, price unit, time]
# 4    [transaction, price unit, seasonal adjustment,...
# ..                                                 ...
# 360                [type, cardholder, data type, time]
# 361                                    [devices, time]
# 362  [withdrawels and deposits, point of operation,...
# 363  [type, direction, geographical coverage, data ...
# 364                [type, initiation, data type, time]
#
# [365 rows x 8 columns]

# %%
tables[tables.id == 'MPK13']
# Out:
#         id         text   unit             updated firstPeriod latestPeriod  \
# 354  MPK13  Share index  Index 2022-03-25 08:00:00     1996M01      2022M02
#
#      active     variables
# 354    True  [type, time]

# %%
indk_vars1 = Dst.get_variables(table_id='MPK13')
indk_vars1
# Out:
#      id  text  elimination   time  \
# 0  TYPE  type         True  False
# 1   Tid  time        False   True
#
#                                               values
# 0  [{'id': '10', 'text': 'Total (OMXC end Decembe...
# 1  [{'id': '1996M01', 'text': '1996M01'}, {'id': ...

# %%
for id in ['TYPE']:
    print(id)
    values = indk_vars1.loc[indk_vars1.id == id,['values']].values[0,0]
    for value in values:      
        print(f' id = {value["id"]}, text = {value["text"]}')
# Out:
# TYPE
#  id = 10, text = Total (OMXC end December 1995 = 100)
#  id = 57, text = OMXC 20 Cap (28th November 2011 = 400)
#  id = 60, text = OMXC 20 (3rd july 1989 = 100)
#  id = 75, text = MidCap+ (end December 2002 = 100)
#  id = 80, text = SmallCap+  (end December 2002 = 100)
#  id = 85, text = OMXC 25 (19th dec 2016 = 1.000)
#  id = 13, text = Energy
#  id = 15, text = Materials
#  id = 20, text = Industrials
#  id = 25, text = Consumer discretions
#  id = 30, text = Consumer Services
#  id = 35, text = Health Care
#  id = 40, text = Financials
#  id = 45, text = Information technology
#  id = 55, text = Utilities

# %%
variables1 = {'TYPE':['85'],'Tid':['*']}
stock = Dst.get_data(table_id = 'MPK13', variables=variables1)
stock.sort_values(by=['TID'], inplace=True)
stock.head(5)
# Out:
#                               TYPE      TID INDHOLD
# 0  OMXC 25 (19th dec 2016 = 1.000)  1996M01      ..
# 1  OMXC 25 (19th dec 2016 = 1.000)  1996M02      ..
# 2  OMXC 25 (19th dec 2016 = 1.000)  1996M03      ..
# 3  OMXC 25 (19th dec 2016 = 1.000)  1996M04      ..
# 4  OMXC 25 (19th dec 2016 = 1.000)  1996M05      ..

# %%
# Code for setting 'TID' as index
# stock.set_index('TID', inplace=True)

# %%
print(stock.INDHOLD == '..')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 309    False
# 310    False
# 311    False
# 312    False
# 313    False
# Name: INDHOLD, Length: 314, dtype: bool

# %%
# Dropping empty rows

stock = stock[stock.INDHOLD != '..']

stock.head(5)
# Out:
#                                 TYPE      TID INDHOLD
# 251  OMXC 25 (19th dec 2016 = 1.000)  2016M12    1016
# 252  OMXC 25 (19th dec 2016 = 1.000)  2017M01    1050
# 253  OMXC 25 (19th dec 2016 = 1.000)  2017M02    1060
# 254  OMXC 25 (19th dec 2016 = 1.000)  2017M03    1075
# 255  OMXC 25 (19th dec 2016 = 1.000)  2017M04    1126

# %%
print(stock.dtypes)
# Out:
# TYPE       object
# TID        object
# INDHOLD    object
# dtype: object

# %%
# Changing 'Indhold' to numeric values

stock['INDHOLD'] = pd.to_numeric(stock['INDHOLD'])

print(stock.dtypes)
# Out:
# TYPE       object
# TID        object
# INDHOLD     int64
# dtype: object

# %%
stock['TID'] = stock['TID'].str.replace('M03','Q1')
stock['TID'] = stock['TID'].str.replace('M06','Q2')
stock['TID'] = stock['TID'].str.replace('M09','Q3')
stock['TID'] = stock['TID'].str.replace('M12','Q4')

stock.head(10)
# Out:
#                                 TYPE      TID  INDHOLD
# 251  OMXC 25 (19th dec 2016 = 1.000)   2016Q4     1016
# 252  OMXC 25 (19th dec 2016 = 1.000)  2017M01     1050
# 253  OMXC 25 (19th dec 2016 = 1.000)  2017M02     1060
# 254  OMXC 25 (19th dec 2016 = 1.000)   2017Q1     1075
# 255  OMXC 25 (19th dec 2016 = 1.000)  2017M04     1126
# 256  OMXC 25 (19th dec 2016 = 1.000)  2017M05     1150
# 257  OMXC 25 (19th dec 2016 = 1.000)   2017Q2     1143
# 258  OMXC 25 (19th dec 2016 = 1.000)  2017M07     1169
# 259  OMXC 25 (19th dec 2016 = 1.000)  2017M08     1172
# 260  OMXC 25 (19th dec 2016 = 1.000)   2017Q3     1174

# %%
# Dropping rows in TID that contain 'M'

stock = stock[stock['TID'].str.contains('M')==False]

# Resetting index

stock = stock.reset_index(drop=True)
stock.head(5)
# Out:
#                               TYPE     TID  INDHOLD
# 0  OMXC 25 (19th dec 2016 = 1.000)  2016Q4     1016
# 1  OMXC 25 (19th dec 2016 = 1.000)  2017Q1     1075
# 2  OMXC 25 (19th dec 2016 = 1.000)  2017Q2     1143
# 3  OMXC 25 (19th dec 2016 = 1.000)  2017Q3     1174
# 4  OMXC 25 (19th dec 2016 = 1.000)  2017Q4     1146

# %%
# Plot of closing values, monthly

stock.plot(x = 'TID', y = 'INDHOLD', kind = 'line', ylabel = "Stock price", xlabel = "Time", label =" ")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Stock price'>

# %% [markdown]
# **Merging data**

# %%
complete = pd.merge(empl,stock,on=['TID'],how='outer')
complete.tail(5)
# Out:
#          BESKSTATUS     TID  INDHOLD_x                             TYPE  \
# 51  Employment rate  2020Q4       74.6  OMXC 25 (19th dec 2016 = 1.000)
# 52  Employment rate  2021Q1       74.1  OMXC 25 (19th dec 2016 = 1.000)
# 53  Employment rate  2021Q2       75.3  OMXC 25 (19th dec 2016 = 1.000)
# 54  Employment rate  2021Q3       75.9  OMXC 25 (19th dec 2016 = 1.000)
# 55  Employment rate  2021Q4       76.5  OMXC 25 (19th dec 2016 = 1.000)
#
#     INDHOLD_y
# 51     1677.0
# 52     1690.0
# 53     1860.0
# 54     1881.0
# 55     1966.0

# %%
# Renaming variables

complete.rename(columns = {'INDHOLD_x':'Employment', 'INDHOLD_y':'Stockmarket'}, inplace = True)
complete.tail(5)
# Out:
#          BESKSTATUS     TID  Employment                             TYPE  \
# 51  Employment rate  2020Q4        74.6  OMXC 25 (19th dec 2016 = 1.000)
# 52  Employment rate  2021Q1        74.1  OMXC 25 (19th dec 2016 = 1.000)
# 53  Employment rate  2021Q2        75.3  OMXC 25 (19th dec 2016 = 1.000)
# 54  Employment rate  2021Q3        75.9  OMXC 25 (19th dec 2016 = 1.000)
# 55  Employment rate  2021Q4        76.5  OMXC 25 (19th dec 2016 = 1.000)
#
#     Stockmarket
# 51       1677.0
# 52       1690.0
# 53       1860.0
# 54       1881.0
# 55       1966.0

# %%
complete['dEmp'] = complete['Employment']/complete['Employment'].shift(1) - 1
complete['dStock'] = complete['Stockmarket']/complete['Stockmarket'].shift(1) - 1
complete.tail(5)
# Out:
#          BESKSTATUS     TID  Employment                             TYPE  \
# 51  Employment rate  2020Q4        74.6  OMXC 25 (19th dec 2016 = 1.000)
# 52  Employment rate  2021Q1        74.1  OMXC 25 (19th dec 2016 = 1.000)
# 53  Employment rate  2021Q2        75.3  OMXC 25 (19th dec 2016 = 1.000)
# 54  Employment rate  2021Q3        75.9  OMXC 25 (19th dec 2016 = 1.000)
# 55  Employment rate  2021Q4        76.5  OMXC 25 (19th dec 2016 = 1.000)
#
#     Stockmarket      dEmp    dStock
# 51       1677.0  0.008108  0.112069
# 52       1690.0 -0.006702  0.007752
# 53       1860.0  0.016194  0.100592
# 54       1881.0  0.007968  0.011290
# 55       1966.0  0.007905  0.045189

# %%
# Correlation plot of change in employment and change in stock market index

complete.plot(x = 'dEmp', y = 'dStock', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='dEmp', ylabel='dStock'>

# %% [markdown]
# There seems to be a largely positive correlation with one outlier.

# %% [markdown]
# # Change in GDP and employment level

# %% [markdown]
# We also wish to see the correlation between a change in GDP level and a change in employment level in OECD countries and make an interactive plot over time. Data is fetched from https://stats.oecd.org/.

# %%
gdp_data = pd.read_csv("SNA_TABLE1_17042022034132194.csv")

#Cleaning and dropping data which is not needed

gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('BRIICS') == False]
gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('EU27_2020') == False]
gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('EA19') == False]
gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('OECD') == False]
gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('G-7') == False]

gdp_data = gdp_data.reset_index(drop=True)

pd.set_option('display.max_rows', 10)

# we wish to look at the period 1996-2016 because there are no missing values here.

gdp_data = gdp_data[gdp_data.Year >= 1996]
gdp_data = gdp_data[gdp_data.Year <= 2016]
gdp_data
# Out:
#      LOCATION    Country TRANSACT  \
# 0         AUS  Australia    B1_GE
# 1         AUS  Australia    B1_GE
# 2         AUS  Australia    B1_GE
# 3         AUS  Australia    B1_GE
# 4         AUS  Australia    B1_GE
# ...       ...        ...      ...
# 1243      HRV    Croatia    B1_GE
# 1244      HRV    Croatia    B1_GE
# 1245      HRV    Croatia    B1_GE
# 1246      HRV    Croatia    B1_GE
# 1247      HRV    Croatia    B1_GE
#
#                                         Transaction MEASURE      Measure  \
# 0     Gross domestic product (expenditure approach)       G  Growth rate
# 1     Gross domestic product (expenditure approach)       G  Growth rate
# 2     Gross domestic product (expenditure approach)       G  Growth rate
# 3     Gross domestic product (expenditure approach)       G  Growth rate
# 4     Gross domestic product (expenditure approach)       G  Growth rate
# ...                                             ...     ...          ...
# 1243  Gross domestic product (expenditure approach)       G  Growth rate
# 1244  Gross domestic product (expenditure approach)       G  Growth rate
# 1245  Gross domestic product (expenditure approach)       G  Growth rate
# 1246  Gross domestic product (expenditure approach)       G  Growth rate
# 1247  Gross domestic product (expenditure approach)       G  Growth rate
#
#       TIME  Year Unit Code        Unit  PowerCode Code PowerCode  \
# 0     1996  1996        PC  Percentage               0     Units
# 1     1997  1997        PC  Percentage               0     Units
# 2     1998  1998        PC  Percentage               0     Units
# 3     1999  1999        PC  Percentage               0     Units
# 4     2000  2000        PC  Percentage               0     Units
# ...    ...   ...       ...         ...             ...       ...
# 1243  2012  2012        PC  Percentage               0     Units
# 1244  2013  2013        PC  Percentage               0     Units
# 1245  2014  2014        PC  Percentage               0     Units
# 1246  2015  2015        PC  Percentage               0     Units
# 1247  2016  2016        PC  Percentage               0     Units
#
#       Reference Period Code  Reference Period     Value Flag Codes Flags
# 0                       NaN               NaN  3.908291        NaN   NaN
# 1                       NaN               NaN  4.614012        NaN   NaN
# 2                       NaN               NaN  4.936675        NaN   NaN
# 3                       NaN               NaN  3.912428        NaN   NaN
# 4                       NaN               NaN  2.038301        NaN   NaN
# ...                     ...               ...       ...        ...   ...
# 1243                    NaN               NaN -2.275707        NaN   NaN
# 1244                    NaN               NaN -0.363117        NaN   NaN
# 1245                    NaN               NaN -0.345947        NaN   NaN
# 1246                    NaN               NaN  2.525688        NaN   NaN
# 1247                    NaN               NaN  3.532432        NaN   NaN
#
# [1052 rows x 17 columns]

# %%
# data for change in employment level (in percent)

emp_data = pd.read_csv("PDBI_I4_16042022200327428.csv")

emp_data = emp_data[emp_data['SUBJECT'].str.contains('I4_ANA_EMPTO') == True]
emp_data = emp_data[emp_data['LOCATION'].str.contains('EU27_2020') == False]
emp_data = emp_data[emp_data['LOCATION'].str.contains('EA19') == False]
emp_data = emp_data[emp_data['LOCATION'].str.contains('OECD') == False]
emp_data = emp_data[emp_data['LOCATION'].str.contains('G-7') == False]
emp_data = emp_data[emp_data['Activity'].str.contains('Total') == True]
emp_data = emp_data.reset_index(drop=True)

emp_data = emp_data[emp_data.Time >= 1996]
emp_data = emp_data[emp_data.Time <= 2016]
emp_data
# Out:
#     LOCATION    Country       SUBJECT  \
# 1        AUS  Australia  I4_ANA_EMPTO
# 2        AUS  Australia  I4_ANA_EMPTO
# 3        AUS  Australia  I4_ANA_EMPTO
# 4        AUS  Australia  I4_ANA_EMPTO
# 5        AUS  Australia  I4_ANA_EMPTO
# ..       ...        ...           ...
# 975      IDN  Indonesia  I4_ANA_EMPTO
# 976      IDN  Indonesia  I4_ANA_EMPTO
# 977      IDN  Indonesia  I4_ANA_EMPTO
# 978      IDN  Indonesia  I4_ANA_EMPTO
# 980      COL   Colombia  I4_ANA_EMPTO
#
#                                            Subject MEASURE  \
# 1    Total employment (number of persons employed)     GRW
# 2    Total employment (number of persons employed)     GRW
# 3    Total employment (number of persons employed)     GRW
# 4    Total employment (number of persons employed)     GRW
# 5    Total employment (number of persons employed)     GRW
# ..                                             ...     ...
# 975  Total employment (number of persons employed)     GRW
# 976  Total employment (number of persons employed)     GRW
# 977  Total employment (number of persons employed)     GRW
# 978  Total employment (number of persons employed)     GRW
# 980  Total employment (number of persons employed)     GRW
#
#                   Measure ACTIVITY Activity  TIME  Time Unit Code        Unit  \
# 1    Annual growth/change      A_U   Total   1996  1996        PC  Percentage
# 2    Annual growth/change      A_U   Total   1997  1997        PC  Percentage
# 3    Annual growth/change      A_U   Total   1998  1998        PC  Percentage
# 4    Annual growth/change      A_U   Total   1999  1999        PC  Percentage
# 5    Annual growth/change      A_U   Total   2000  2000        PC  Percentage
# ..                    ...      ...      ...   ...   ...       ...         ...
# 975  Annual growth/change      A_U   Total   2013  2013        PC  Percentage
# 976  Annual growth/change      A_U   Total   2014  2014        PC  Percentage
# 977  Annual growth/change      A_U   Total   2015  2015        PC  Percentage
# 978  Annual growth/change      A_U   Total   2016  2016        PC  Percentage
# 980  Annual growth/change      A_U   Total   2016  2016        PC  Percentage
#
#      PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 1                 0     Units                    NaN               NaN
# 2                 0     Units                    NaN               NaN
# 3                 0     Units                    NaN               NaN
# 4                 0     Units                    NaN               NaN
# 5                 0     Units                    NaN               NaN
# ..              ...       ...                    ...               ...
# 975               0     Units                    NaN               NaN
# 976               0     Units                    NaN               NaN
# 977               0     Units                    NaN               NaN
# 978               0     Units                    NaN               NaN
# 980               0     Units                    NaN               NaN
#
#         Value  Flag Codes  Flags
# 1    0.398463         NaN    NaN
# 2    1.828934         NaN    NaN
# 3    1.461592         NaN    NaN
# 4    3.003300         NaN    NaN
# 5    1.575063         NaN    NaN
# ..        ...         ...    ...
# 975  0.227727         NaN    NaN
# 976  1.655672         NaN    NaN
# 977  0.166777         NaN    NaN
# 978  3.129071         NaN    NaN
# 980  0.631093         NaN    NaN
#
# [791 rows x 19 columns]

# %% [markdown]
# Looking at the difference in our data:

# %%
print(f'Years in emp: {emp_data.TIME.unique()}')
print(f'countries in emp = {len(emp_data.Country.unique())}')
print(f'Years in gdp: {gdp_data.TIME.unique()}')
print(f'countries in gdp = {len(gdp_data.Country.unique())}')
# Out:
# Years in emp: [1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015 2016]
# countries in emp = 40
# Years in gdp: [1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015 2016]
# countries in gdp = 51

# %%
diff_y = [y for y in gdp_data.TIME.unique() if y not in emp_data.TIME.unique()] 
print(f'years in gdp_data, but not in emp_data data: {diff_y}')

diff_y = [y for y in emp_data.TIME.unique() if y not in gdp_data.TIME.unique()] 
print(f'years in emp_data, but not in gdp_data data: {diff_y}')

diff_m = [m for m in gdp_data.Country.unique() if m not in emp_data.Country.unique()] 
print(f'countries in gdp data, but not in emp data: {diff_m}')

diff_m = [m for m in emp_data.Country.unique() if m not in gdp_data.Country.unique()] 
print(f'countries in emp data, but not in gdp data: {diff_m}')
# Out:
# years in gdp_data, but not in emp_data data: []
# years in emp_data, but not in gdp_data data: []
# countries in gdp data, but not in emp data: ["China (People's Republic of)", 'India', 'Russia', 'Turkey', 'Saudi Arabia', 'Argentina', 'Cyprus', 'Bulgaria', 'Romania', 'Malta', 'Croatia']
# countries in emp data, but not in gdp data: []

# %% [markdown]
# We see that there appears to be countries in one dataset which does not exist in the other.

# %%
# Further cleaning

gdp_data = gdp_data[gdp_data['Country'].str.contains('India') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Russia') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Turkey') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Saudi Arabia') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Argentina') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Cyprus') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Bulgaria') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Romania') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Malta') == False]
gdp_data = gdp_data[gdp_data['Country'].str.contains('Croatia') == False]
gdp_data = gdp_data[gdp_data['LOCATION'].str.contains('CHN') == False]
gdp_data = gdp_data.reset_index(drop=True)

# %% [markdown]
# **Merged data**

# %%
merged_data = pd.merge(gdp_data,emp_data,on=['TIME', 'LOCATION'],how='outer')
pd.set_option('display.max_columns', None)

# droppong NaNs

merged_data = merged_data.dropna(subset=['Value_x'])
merged_data = merged_data.dropna(subset=['Value_y'])

# Renaming variables

merged_data.rename(columns = {'Value_x':'dGDP', 'Value_y':'dEMP'}, inplace = True)

merged_data
# Out:
#     LOCATION   Country_x TRANSACT  \
# 0        AUS   Australia    B1_GE
# 1        AUS   Australia    B1_GE
# 2        AUS   Australia    B1_GE
# 3        AUS   Australia    B1_GE
# 4        AUS   Australia    B1_GE
# ..       ...         ...      ...
# 830      CRI  Costa Rica    B1_GE
# 831      CRI  Costa Rica    B1_GE
# 832      CRI  Costa Rica    B1_GE
# 833      CRI  Costa Rica    B1_GE
# 834      CRI  Costa Rica    B1_GE
#
#                                        Transaction MEASURE_x    Measure_x  \
# 0    Gross domestic product (expenditure approach)         G  Growth rate
# 1    Gross domestic product (expenditure approach)         G  Growth rate
# 2    Gross domestic product (expenditure approach)         G  Growth rate
# 3    Gross domestic product (expenditure approach)         G  Growth rate
# 4    Gross domestic product (expenditure approach)         G  Growth rate
# ..                                             ...       ...          ...
# 830  Gross domestic product (expenditure approach)         G  Growth rate
# 831  Gross domestic product (expenditure approach)         G  Growth rate
# 832  Gross domestic product (expenditure approach)         G  Growth rate
# 833  Gross domestic product (expenditure approach)         G  Growth rate
# 834  Gross domestic product (expenditure approach)         G  Growth rate
#
#      TIME  Year Unit Code_x      Unit_x  PowerCode Code_x PowerCode_x  \
# 0    1996  1996          PC  Percentage                 0       Units
# 1    1997  1997          PC  Percentage                 0       Units
# 2    1998  1998          PC  Percentage                 0       Units
# 3    1999  1999          PC  Percentage                 0       Units
# 4    2000  2000          PC  Percentage                 0       Units
# ..    ...   ...         ...         ...               ...         ...
# 830  2012  2012          PC  Percentage                 0       Units
# 831  2013  2013          PC  Percentage                 0       Units
# 832  2014  2014          PC  Percentage                 0       Units
# 833  2015  2015          PC  Percentage                 0       Units
# 834  2016  2016          PC  Percentage                 0       Units
#
#      Reference Period Code_x  Reference Period_x      dGDP Flag Codes_x  \
# 0                        NaN                 NaN  3.908291          NaN
# 1                        NaN                 NaN  4.614012          NaN
# 2                        NaN                 NaN  4.936675          NaN
# 3                        NaN                 NaN  3.912428          NaN
# 4                        NaN                 NaN  2.038301          NaN
# ..                       ...                 ...       ...          ...
# 830                      NaN                 NaN  4.882592          NaN
# 831                      NaN                 NaN  2.494766          NaN
# 832                      NaN                 NaN  3.542110          NaN
# 833                      NaN                 NaN  3.652081          NaN
# 834                      NaN                 NaN  4.204323          NaN
#
#     Flags_x   Country_y       SUBJECT  \
# 0       NaN   Australia  I4_ANA_EMPTO
# 1       NaN   Australia  I4_ANA_EMPTO
# 2       NaN   Australia  I4_ANA_EMPTO
# 3       NaN   Australia  I4_ANA_EMPTO
# 4       NaN   Australia  I4_ANA_EMPTO
# ..      ...         ...           ...
# 830     NaN  Costa Rica  I4_ANA_EMPTO
# 831     NaN  Costa Rica  I4_ANA_EMPTO
# 832     NaN  Costa Rica  I4_ANA_EMPTO
# 833     NaN  Costa Rica  I4_ANA_EMPTO
# 834     NaN  Costa Rica  I4_ANA_EMPTO
#
#                                            Subject MEASURE_y  \
# 0    Total employment (number of persons employed)       GRW
# 1    Total employment (number of persons employed)       GRW
# 2    Total employment (number of persons employed)       GRW
# 3    Total employment (number of persons employed)       GRW
# 4    Total employment (number of persons employed)       GRW
# ..                                             ...       ...
# 830  Total employment (number of persons employed)       GRW
# 831  Total employment (number of persons employed)       GRW
# 832  Total employment (number of persons employed)       GRW
# 833  Total employment (number of persons employed)       GRW
# 834  Total employment (number of persons employed)       GRW
#
#                 Measure_y ACTIVITY Activity    Time Unit Code_y      Unit_y  \
# 0    Annual growth/change      A_U   Total   1996.0          PC  Percentage
# 1    Annual growth/change      A_U   Total   1997.0          PC  Percentage
# 2    Annual growth/change      A_U   Total   1998.0          PC  Percentage
# 3    Annual growth/change      A_U   Total   1999.0          PC  Percentage
# 4    Annual growth/change      A_U   Total   2000.0          PC  Percentage
# ..                    ...      ...      ...     ...         ...         ...
# 830  Annual growth/change      A_U   Total   2012.0          PC  Percentage
# 831  Annual growth/change      A_U   Total   2013.0          PC  Percentage
# 832  Annual growth/change      A_U   Total   2014.0          PC  Percentage
# 833  Annual growth/change      A_U   Total   2015.0          PC  Percentage
# 834  Annual growth/change      A_U   Total   2016.0          PC  Percentage
#
#      PowerCode Code_y PowerCode_y  Reference Period Code_y  \
# 0                 0.0       Units                      NaN
# 1                 0.0       Units                      NaN
# 2                 0.0       Units                      NaN
# 3                 0.0       Units                      NaN
# 4                 0.0       Units                      NaN
# ..                ...         ...                      ...
# 830               0.0       Units                      NaN
# 831               0.0       Units                      NaN
# 832               0.0       Units                      NaN
# 833               0.0       Units                      NaN
# 834               0.0       Units                      NaN
#
#      Reference Period_y      dEMP  Flag Codes_y  Flags_y
# 0                   NaN  0.398463           NaN      NaN
# 1                   NaN  1.828934           NaN      NaN
# 2                   NaN  1.461592           NaN      NaN
# 3                   NaN  3.003300           NaN      NaN
# 4                   NaN  1.575063           NaN      NaN
# ..                  ...       ...           ...      ...
# 830                 NaN  8.608253           NaN      NaN
# 831                 NaN  1.285088           NaN      NaN
# 832                 NaN  1.968978           NaN      NaN
# 833                 NaN -0.572385           NaN      NaN
# 834                 NaN -2.675737           NaN      NaN
#
# [791 rows x 34 columns]

# %%
# interactive plot over time


import plotly.express as px

fig = px.scatter(merged_data, x="dEMP", y="dGDP", animation_frame="Time", animation_group="Country_x", hover_name="Country_x",
                )
fig.show()

# %% [markdown]
# We see a clear correlation between a change in GDP and empoloyment levels in OECD countries in years 1996-2016.
